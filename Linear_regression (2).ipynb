# %%
import pandas 
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data=pandas.read_csv('cost_revenue_clean (1).csv')

# %%
x = DataFrame(data,columns=["production_budget_usd"])
#features - indpendet
y = DataFrame(data,columns=["worldwide_gross_usd"])
#target - dependet

# %%
plt.figure(figsize=(10,6))
plt.title(' cost vs income')
plt.xlabel('production BUDGET')
plt.ylabel('production INCOME')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.scatter(x,y,alpha=0.3)
plt.show()

# %%
linear = LinearRegression()
linear.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coffient:

# %%
linear.coef_  #theta_1
# Out:
# array([[3.11150918]])

# %%
#intercept
linear.intercept_
# Out:
# array([-7236192.72913958])

# %% [markdown]
# h0(x)=0o+01x
# 0o = -7.2336 -----> y intercept
# 01 = 3.1115  -----> slope
#
# predict revunue for a film with a 50$ million budget
# ho(x)=-7.236 + 3.115*50000000

# %%
plt.figure(figsize=(10,6))
plt.title('cost vs income')
plt.xlabel('production BUDGET')
plt.ylabel('production INCOME')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)


plt.scatter(x,y,alpha=0.3)
plt.plot(x,linear.predict(x),color='red',linewidth=4)
plt.show()
